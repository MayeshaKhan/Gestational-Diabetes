# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_csv('filtered_diabetes Gestational Diabetes - Dataset 3.csv')
df2 = pd.read_csv('Gestational Diabetes.csv')

# %%
df1
# Out:
#       Age  Pregnancy No  Weight  Height   BMI  Heredity  Prediction
# 0    17.0           0.0    49.0   145.0  23.3         0           0
# 1    17.0           0.0    50.0   145.0  23.8         0           0
# 2    17.0           0.0    49.0   146.0  23.0         0           0
# 3    17.0           0.0    49.0   146.0  23.0         0           0
# 4    16.0           0.0    49.0   147.0  22.7         0           0
# ..    ...           ...     ...     ...   ...       ...         ...
# 183  27.0           1.0    59.0   160.0  23.0         0           0
# 184  18.0           0.0    65.0   164.0  24.2         0           0
# 185  39.0           4.0    68.0   167.0  24.4         1           0
# 186  42.0           3.0    67.0   170.0  23.2         0           0
# 187  33.0           3.0    65.0   167.0  23.3         0           1
#
# [188 rows x 7 columns]

# %%
df1.isnull().sum()
# Out:
# Age             0
# Pregnancy No    0
# Weight          0
# Height          0
# BMI             0
# Heredity        0
# Prediction      0
# dtype: int64

# %%
df2
# Out:
#        Age  Pregnancy No  Weight  Height   BMI  Heredity  Prediction
# 0     17.0           1.0    48.0   165.0  17.6         0           0
# 1     17.0           1.0    49.0   145.0  23.3         0           0
# 2     17.0           1.0    50.0   140.0  25.5         0           0
# 3     17.0           1.0    50.0   145.0  23.8         0           0
# 4     17.0           1.0    49.0   146.0  23.0         0           0
# ...    ...           ...     ...     ...   ...       ...         ...
# 1007  35.0           3.0    89.0   159.0  35.2         1           1
# 1008  41.0           4.0    87.0   165.0  32.0         0           0
# 1009  34.0           2.0    67.0   160.0  26.2         1           0
# 1010  33.0           3.0    65.0   167.0  23.3         0           1
# 1011  28.0           2.0    68.0   156.0  27.9         0           0
#
# [1012 rows x 7 columns]

# %%
df1.isnull().sum()
# Out:
# Age             0
# Pregnancy No    0
# Weight          0
# Height          0
# BMI             0
# Heredity        0
# Prediction      0
# dtype: int64

# %%
df3 = pd.read_excel('Gestational Diabetic Data Set.xlsx')

# %%
df3
# Out:
#       Case Number  Age  No of Pregnancy  Gestation in previous Pregnancy  \
# 0               1   22                2                                1
# 1               2   26                2                                1
# 2               3   29                1                                0
# 3               4   28                2                                1
# 4               5   21                2                                1
# ...           ...  ...              ...                              ...
# 3520         3521   31                4                                1
# 3521         3522   26                3                                1
# 3522         3523   35                2                                2
# 3523         3524   37                2                                0
# 3524         3525   43                2                                0
#
#        BMI   HDL  Family History  unexplained prenetal loss  \
# ...

# %%
df3.isnull().sum()
# Out:
# Case Number                           0
# Age                                   0
# No of Pregnancy                       0
# Gestation in previous Pregnancy       0
# BMI                                1081
# HDL                                1001
# Family History                        0
# unexplained prenetal loss             0
# Large Child or Birth Default          0
# PCOS                                  0
# Sys BP                             1705
# Dia BP                                0
# OGTT                                513
# Hemoglobin                            0
# Sedentary Lifestyle                   0
# Prediabetes                           0
# Class Label(GDM /Non GDM)             0
# dtype: int64

# %%
df3['BMI'].mean()
# Out:
# 27.854091653027822

# %%
df3['BMI'].median()
# Out:
# 27.5

# %%
df3['BMI'] = df3['BMI'].fillna(df3['BMI'].mean())

# %%
df3.isnull().sum()
# Out:
# Case Number                           0
# Age                                   0
# No of Pregnancy                       0
# Gestation in previous Pregnancy       0
# BMI                                   0
# HDL                                1001
# Family History                        0
# unexplained prenetal loss             0
# Large Child or Birth Default          0
# PCOS                                  0
# Sys BP                             1705
# Dia BP                                0
# OGTT                                513
# Hemoglobin                            0
# Sedentary Lifestyle                   0
# Prediabetes                           0
# Class Label(GDM /Non GDM)             0
# dtype: int64

# %%
HDL_Mean= df3['HDL'].mean()
HDL_Mean
# Out:
# 46.47187004754358

# %%
HDL_Median= df3['HDL'].median()
HDL_Median
# Out:
# 49.0

# %%
import seaborn as sns
sns.histplot(df3['HDL'], kde=True)
# Out:
# <Axes: xlabel='HDL', ylabel='Count'>

# %% [markdown]
# Outlier handaling

# %%
HDL_std = df3['HDL'].std() #Calculate Standard Deviation
HDL_std
# Out:
# 10.800812545096528

# %%
std_plus_3 = HDL_Mean + (3 * HDL_std ) 
std_plus_3
# Out:
# 78.87430768283318

# %%
neg_std_3 = HDL_Mean - (3 * HDL_std )  
neg_std_3
# Out:
# 14.069432412253995

# %%
df3[df3['HDL'] > std_plus_3]   #Outlier
# Out:
# Empty DataFrame
# Columns: [Case Number, Age, No of Pregnancy, Gestation in previous Pregnancy, BMI, HDL, Family History, unexplained prenetal loss, Large Child or Birth Default, PCOS, Sys BP, Dia BP, OGTT, Hemoglobin, Sedentary Lifestyle, Prediabetes, Class Label(GDM /Non GDM)]
# Index: []

# %%
df3[df3['HDL'] < neg_std_3]   #Outlier
# Out:
# Empty DataFrame
# Columns: [Case Number, Age, No of Pregnancy, Gestation in previous Pregnancy, BMI, HDL, Family History, unexplained prenetal loss, Large Child or Birth Default, PCOS, Sys BP, Dia BP, OGTT, Hemoglobin, Sedentary Lifestyle, Prediabetes, Class Label(GDM /Non GDM)]
# Index: []

# %%
merge_outliers = df3[(df3['HDL'] > std_plus_3) | (df3['HDL'] < neg_std_3)]   # Merge two type of outliers

merge_outliers
# Out:
# Empty DataFrame
# Columns: [Case Number, Age, No of Pregnancy, Gestation in previous Pregnancy, BMI, HDL, Family History, unexplained prenetal loss, Large Child or Birth Default, PCOS, Sys BP, Dia BP, OGTT, Hemoglobin, Sedentary Lifestyle, Prediabetes, Class Label(GDM /Non GDM)]
# Index: []

# %%
merge_outliers.shape
# Out:
# (0, 17)

# %%
preprocessed_df3 = df3[(df3['HDL'] < std_plus_3) & (df3['HDL'] > neg_std_3)]  #drop all outliers
preprocessed_df3
# Out:
#       Case Number  Age  No of Pregnancy  Gestation in previous Pregnancy  \
# 0               1   22                2                                1
# 1               2   26                2                                1
# 2               3   29                1                                0
# 3               4   28                2                                1
# 4               5   21                2                                1
# ...           ...  ...              ...                              ...
# 3520         3521   31                4                                1
# 3521         3522   26                3                                1
# 3522         3523   35                2                                2
# 3523         3524   37                2                                0
# 3524         3525   43                2                                0
#
#             BMI   HDL  Family History  unexplained prenetal loss  \
# ...

# %%
sns.histplot(preprocessed_df3['HDL'], kde=True)
# Out:
# <Axes: xlabel='HDL', ylabel='Count'>

# %%
#one hot encoding
dummy_variables = pd.get_dummies(preprocessed_df3['HDL'], drop_first=True)  #true means it will drop one dummy variable

# %%
new_df3_1=  preprocessed_df3.drop('HDL',axis=1)
new_df3_1
# Out:
#       Case Number  Age  No of Pregnancy  Gestation in previous Pregnancy  \
# 0               1   22                2                                1
# 1               2   26                2                                1
# 2               3   29                1                                0
# 3               4   28                2                                1
# 4               5   21                2                                1
# ...           ...  ...              ...                              ...
# 3520         3521   31                4                                1
# 3521         3522   26                3                                1
# 3522         3523   35                2                                2
# 3523         3524   37                2                                0
# 3524         3525   43                2                                0
#
#             BMI  Family History  unexplained prenetal loss  \
# ...

# %%
df3_1 = pd.concat([new_df3_1,dummy_variables], axis=1) #Concat two data frame
df3_1
# Out:
#       Case Number  Age  No of Pregnancy  Gestation in previous Pregnancy  \
# 0               1   22                2                                1
# 1               2   26                2                                1
# 2               3   29                1                                0
# 3               4   28                2                                1
# 4               5   21                2                                1
# ...           ...  ...              ...                              ...
# 3520         3521   31                4                                1
# 3521         3522   26                3                                1
# 3522         3523   35                2                                2
# 3523         3524   37                2                                0
# 3524         3525   43                2                                0
#
#             BMI  Family History  unexplained prenetal loss  \
# ...

# %%
import seaborn as sns
sns.histplot(df3['OGTT'], kde=True)
# Out:
# <Axes: xlabel='OGTT', ylabel='Count'>

# %%
OGTT_Mean= df3['OGTT'].mean()
OGTT_Mean
# Out:
# 170.70750332005312

# %%
preprocessed_df3.isnull().sum()
# Out:
# Case Number                           0
# Age                                   0
# No of Pregnancy                       0
# Gestation in previous Pregnancy       0
# BMI                                   0
# HDL                                   0
# Family History                        0
# unexplained prenetal loss             0
# Large Child or Birth Default          0
# PCOS                                  0
# Sys BP                             1400
# Dia BP                                0
# OGTT                                513
# Hemoglobin                            0
# Sedentary Lifestyle                   0
# Prediabetes                           0
# Class Label(GDM /Non GDM)             0
# dtype: int64

# %%
std_value = df3['OGTT'].std() #Calculate Standard Deviation
std_value
# Out:
# 48.16054916274915

# %%
std_plus_3 = OGTT_Mean + (3 * std_value )
std_plus_3
# Out:
# 315.1891508083006

# %%
neg_std_3 = OGTT_Mean - (3 * std_value )  #you can use 2.5 std to more clean
neg_std_3
# Out:
# 26.22585583180566

# %%
merge_outliers = df3[(df3['OGTT'] > std_plus_3) | (df3['OGTT'] < neg_std_3)]   # Merge two type of outliers
merge_outliers
# Out:
#       Case Number  Age  No of Pregnancy  Gestation in previous Pregnancy  \
# 3250         3251   28                1                                0
# 3251         3252   32                2                                2
# 3253         3254   42                1                                0
# 3254         3255   44                2                                2
# 3255         3256   28                3                                2
# ...           ...  ...              ...                              ...
# 3319         3320   41                3                                2
# 3320         3321   35                3                                2
# 3321         3322   36                1                                0
# 3322         3323   38                2                                2
# 3324         3325   36                3                                2
#
#        BMI   HDL  Family History  unexplained prenetal loss  \
# ...

# %%
OGTT_df3 = df3[(df3['OGTT'] < std_plus_3) & (df3['OGTT'] > neg_std_3)]  #drop all outlier
OGTT_df3
# Out:
#       Case Number  Age  No of Pregnancy  Gestation in previous Pregnancy  \
# 513           514   34                1                                0
# 514           515   32                1                                0
# 515           516   34                1                                0
# 516           517   32                2                                1
# 517           518   32                1                                0
# ...           ...  ...              ...                              ...
# 3520         3521   31                4                                1
# 3521         3522   26                3                                1
# 3522         3523   35                2                                2
# 3523         3524   37                2                                0
# 3524         3525   43                2                                0
#
#             BMI   HDL  Family History  unexplained prenetal loss  \
# ...
